# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# export PYTHONPATH="$PYTHONPATH:/shared-libs/python3.7/py/lib/python3.7/site-packages"
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting ase
#   Downloading ase-3.22.1-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 63.6 MB/s eta 0:00:00
# Collecting matscipy
#   Downloading matscipy-1.0.0.tar.gz (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 81.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: scipy>=1.1.0 in /shared-libs-deprecated/python3.7/py/lib/python3.7/site-packages (from ase->-r ./requirements.txt (line 1)) (1.7.3)
# Requirement already satisfied: numpy>=1.15.0 in /shared-libs-deprecated/python3.7/py/lib/python3.7/site-packages (from ase->-r ./requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: matplotlib>=3.1.0 in /shared-libs-deprecated/python3.7/py/lib/python3.7/site-packages (from ase->-r ./requirements.txt (line 1)) (3.5.3)
# Collecting looseversion
#   Downloading looseversion-1.3.0-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs-deprecated/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (4.37.4)
# Requirement already satisfied: packaging>=20.0 in /shared-libs-deprecated/python3.7/py-core/lib/python3.7/site-packages (from matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs-deprecated/python3.7/py-core/lib/python3.7/site-packages (from matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs-deprecated/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs-deprecated/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /shared-libs-deprecated/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs-deprecated/python3.7/py-core/lib/python3.7/site-packages (from matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: typing-extensions in /shared-libs-deprecated/python3.7/py-core/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: six>=1.5 in /shared-libs-deprecated/python3.7/py-core/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (1.16.0)
# Building wheels for collected packages: matscipy
#   Building wheel for matscipy (pyproject.toml): started
#   Building wheel for matscipy (pyproject.toml): finished with status 'done'
#   Created wheel for matscipy: filename=matscipy-1.0.0-cp37-cp37m-linux_x86_64.whl size=436022 sha256=d0a766df9e8094bb6e331e8cb049be457250136c6774fea8211f3ae9e502e33e
#   Stored in directory: /root/.cache/pip/wheels/64/42/1b/49a7095981a52a1f439d06ec03c1c1a26c867e59a39e5d661f
# Successfully built matscipy
# Installing collected packages: looseversion, ase, matscipy
# Successfully installed ase-3.22.1 looseversion-1.3.0 matscipy-1.0.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=00126201-02a2-4655-9b63-1cb17da75327' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
